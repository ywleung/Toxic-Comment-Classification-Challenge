# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings("ignore")
import gc

import tensorflow as tf
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

from utils import *
from attention_layer import *
from model import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = ''
train_path = os.path.join(path, 'train.csv')
test_path = os.path.join(path, 'test.csv')
embed_path = os.path.join(path, 'glove.6B.300d.txt')

train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)

# %%
# basic config parameters
embed_size = 300
max_feature = 20000
max_len = 100

num_fold = 10

# %%
list_sentence_train = train_df['comment_text'].values
list_class = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
y_df = train_df[list_class].values

list_sentence_test = test_df['comment_text'].values

# %%
tokenizer = Tokenizer(num_words=max_feature)
tokenizer.fit_on_texts(list(list_sentence_train))
list_tokenized_train = tokenizer.texts_to_sequences(list_sentence_train)

list_tokenized_test = tokenizer.texts_to_sequences(list_sentence_test)
X_df = pad_sequences(list_tokenized_train, maxlen=max_len)
X_test = pad_sequences(list_tokenized_test, maxlen=max_len)

# %%
word_to_index, index_to_word, word_to_vec_map = read_glove_vecs(embed_path)

# %% [markdown]
# Use these vectors to create our embedding matrix, with random initialization for words that aren't in GloVe. We'll use the same mean and stdev of embeddings the GloVe has when generating the random init.

# %%
all_embs = np.stack(word_to_vec_map.values())
emb_mean, emb_std = all_embs.mean(), all_embs.std()
emb_mean, emb_std
# Out:
# (-0.003905011892532385, 0.3817702235076489)

# %%
word_index = tokenizer.word_index
num_word = min(max_feature, len(word_index))
embedding_matrix = np.random.normal(emb_mean, emb_std, (num_word, embed_size))
for word, i in word_index.items():
    if i >= max_feature: continue
    embedding_vector = word_to_vec_map.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector

# %%
kfold = KFold(num_fold, shuffle=True)

# %%
save_model_name = 'biLSTM'
lstm_model = biLSTM_model(embed_size, max_feature, max_len, embedding_matrix)

# %%
kfold_train(kfold, X_df, y_df, lstm_model, save_model_name)
# Out:
# ***************************************************
# *******************   fold  0   *******************
# ***************************************************
# model/biLSTM_fold_0.model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 100, 300)          6000000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 100, 100)          140800
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 306
# =================================================================
# Total params: 6,146,156
# Trainable params: 6,146,156
# Non-trainable params: 0
# _________________________________________________________________
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/30
# 143613/143613 [==============================] - 41s 282us/step - loss: 0.0963 - acc: 0.9713 - val_loss: 0.0490 - val_acc: 0.9821
#
# Epoch 00001: val_loss improved from inf to 0.04904, saving model to model/biLSTM_fold_0.model
# Epoch 2/30
# 143613/143613 [==============================] - 37s 258us/step - loss: 0.0479 - acc: 0.9824 - val_loss: 0.0459 - val_acc: 0.9830
#
# Epoch 00002: val_loss improved from 0.04904 to 0.04588, saving model to model/biLSTM_fold_0.model
# Epoch 3/30
# 143613/143613 [==============================] - 37s 258us/step - loss: 0.0425 - acc: 0.9839 - val_loss: 0.0448 - val_acc: 0.9831
#
# Epoch 00003: val_loss improved from 0.04588 to 0.04479, saving model to model/biLSTM_fold_0.model
# Epoch 4/30
# 143613/143613 [==============================] - 37s 259us/step - loss: 0.0380 - acc: 0.9853 - val_loss: 0.0453 - val_acc: 0.9831
#
# Epoch 00004: val_loss did not improve from 0.04479
# Epoch 5/30
# 143613/143613 [==============================] - 37s 259us/step - loss: 0.0340 - acc: 0.9868 - val_loss: 0.0470 - val_acc: 0.9823
#
# Epoch 00005: val_loss did not improve from 0.04479
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 6/30
# 143613/143613 [==============================] - 37s 258us/step - loss: 0.0293 - acc: 0.9886 - val_loss: 0.0483 - val_acc: 0.9828
#
# Epoch 00006: val_loss did not improve from 0.04479
# Epoch 7/30
# 143613/143613 [==============================] - 37s 259us/step - loss: 0.0267 - acc: 0.9895 - val_loss: 0.0501 - val_acc: 0.9830
#
# Epoch 00007: val_loss did not improve from 0.04479
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 8/30
# 143613/143613 [==============================] - 37s 258us/step - loss: 0.0241 - acc: 0.9906 - val_loss: 0.0520 - val_acc: 0.9825
#
# Epoch 00008: val_loss did not improve from 0.04479
# Epoch 00008: early stopping
# ***************************************************
# *******************   fold  1   *******************
# ***************************************************
# model/biLSTM_fold_1.model
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/30
# 143614/143614 [==============================] - 39s 271us/step - loss: 0.1169 - acc: 0.9676 - val_loss: 0.0511 - val_acc: 0.9814
#
# Epoch 00001: val_loss improved from inf to 0.05111, saving model to model/biLSTM_fold_1.model
# Epoch 2/30
# 143614/143614 [==============================] - 37s 258us/step - loss: 0.0481 - acc: 0.9825 - val_loss: 0.0484 - val_acc: 0.9822
#
# Epoch 00002: val_loss improved from 0.05111 to 0.04837, saving model to model/biLSTM_fold_1.model
# Epoch 3/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0428 - acc: 0.9841 - val_loss: 0.0484 - val_acc: 0.9824
#
# Epoch 00003: val_loss did not improve from 0.04837
# Epoch 4/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0386 - acc: 0.9855 - val_loss: 0.0492 - val_acc: 0.9814
#
# Epoch 00004: val_loss did not improve from 0.04837
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 5/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0334 - acc: 0.9872 - val_loss: 0.0500 - val_acc: 0.9817
#
# Epoch 00005: val_loss did not improve from 0.04837
# Epoch 6/30
# 143614/143614 [==============================] - 37s 258us/step - loss: 0.0306 - acc: 0.9883 - val_loss: 0.0521 - val_acc: 0.9809
#
# Epoch 00006: val_loss did not improve from 0.04837
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 7/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0277 - acc: 0.9895 - val_loss: 0.0554 - val_acc: 0.9816
#
# Epoch 00007: val_loss did not improve from 0.04837
# Epoch 00007: early stopping
# ***************************************************
# *******************   fold  2   *******************
# ***************************************************
# model/biLSTM_fold_2.model
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/30
# 143614/143614 [==============================] - 39s 274us/step - loss: 0.1406 - acc: 0.9534 - val_loss: 0.0558 - val_acc: 0.9809
#
# Epoch 00001: val_loss improved from inf to 0.05576, saving model to model/biLSTM_fold_2.model
# Epoch 2/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0513 - acc: 0.9819 - val_loss: 0.0497 - val_acc: 0.9824
#
# Epoch 00002: val_loss improved from 0.05576 to 0.04972, saving model to model/biLSTM_fold_2.model
# Epoch 3/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0459 - acc: 0.9833 - val_loss: 0.0492 - val_acc: 0.9825
#
# Epoch 00003: val_loss improved from 0.04972 to 0.04920, saving model to model/biLSTM_fold_2.model
# Epoch 4/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0424 - acc: 0.9845 - val_loss: 0.0487 - val_acc: 0.9826
#
# Epoch 00004: val_loss improved from 0.04920 to 0.04869, saving model to model/biLSTM_fold_2.model
# Epoch 5/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0390 - acc: 0.9855 - val_loss: 0.0500 - val_acc: 0.9824
#
# Epoch 00005: val_loss did not improve from 0.04869
# Epoch 6/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0361 - acc: 0.9865 - val_loss: 0.0507 - val_acc: 0.9824
#
# Epoch 00006: val_loss did not improve from 0.04869
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0320 - acc: 0.9880 - val_loss: 0.0528 - val_acc: 0.9821
#
# Epoch 00007: val_loss did not improve from 0.04869
# Epoch 8/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0298 - acc: 0.9888 - val_loss: 0.0542 - val_acc: 0.9819
#
# Epoch 00008: val_loss did not improve from 0.04869
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 9/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0274 - acc: 0.9898 - val_loss: 0.0561 - val_acc: 0.9820
#
# Epoch 00009: val_loss did not improve from 0.04869
# Epoch 00009: early stopping
# ***************************************************
# *******************   fold  3   *******************
# ***************************************************
# model/biLSTM_fold_3.model
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/30
# 143614/143614 [==============================] - 40s 276us/step - loss: 0.1241 - acc: 0.9647 - val_loss: 0.0526 - val_acc: 0.9811
#
# Epoch 00001: val_loss improved from inf to 0.05260, saving model to model/biLSTM_fold_3.model
# Epoch 2/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0485 - acc: 0.9825 - val_loss: 0.0505 - val_acc: 0.9819
#
# Epoch 00002: val_loss improved from 0.05260 to 0.05048, saving model to model/biLSTM_fold_3.model
# Epoch 3/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0434 - acc: 0.9840 - val_loss: 0.0501 - val_acc: 0.9819
#
# Epoch 00003: val_loss improved from 0.05048 to 0.05007, saving model to model/biLSTM_fold_3.model
# Epoch 4/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0398 - acc: 0.9852 - val_loss: 0.0519 - val_acc: 0.9821
#
# Epoch 00004: val_loss did not improve from 0.05007
# Epoch 5/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0360 - acc: 0.9866 - val_loss: 0.0527 - val_acc: 0.9814
#
# Epoch 00005: val_loss did not improve from 0.05007
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 6/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0312 - acc: 0.9882 - val_loss: 0.0558 - val_acc: 0.9811
#
# Epoch 00006: val_loss did not improve from 0.05007
# Epoch 7/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0286 - acc: 0.9892 - val_loss: 0.0576 - val_acc: 0.9807
#
# Epoch 00007: val_loss did not improve from 0.05007
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 8/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0257 - acc: 0.9903 - val_loss: 0.0614 - val_acc: 0.9814
#
# Epoch 00008: val_loss did not improve from 0.05007
# Epoch 00008: early stopping
# ***************************************************
# *******************   fold  4   *******************
# ***************************************************
# model/biLSTM_fold_4.model
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/30
# 143614/143614 [==============================] - 40s 276us/step - loss: 0.1578 - acc: 0.9346 - val_loss: 0.0492 - val_acc: 0.9825
#
# Epoch 00001: val_loss improved from inf to 0.04922, saving model to model/biLSTM_fold_4.model
# Epoch 2/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0508 - acc: 0.9819 - val_loss: 0.0466 - val_acc: 0.9831
#
# Epoch 00002: val_loss improved from 0.04922 to 0.04662, saving model to model/biLSTM_fold_4.model
# Epoch 3/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0451 - acc: 0.9834 - val_loss: 0.0461 - val_acc: 0.9835
#
# Epoch 00003: val_loss improved from 0.04662 to 0.04605, saving model to model/biLSTM_fold_4.model
# Epoch 4/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0415 - acc: 0.9846 - val_loss: 0.0463 - val_acc: 0.9835
#
# Epoch 00004: val_loss did not improve from 0.04605
# Epoch 5/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0383 - acc: 0.9856 - val_loss: 0.0477 - val_acc: 0.9832
#
# Epoch 00005: val_loss did not improve from 0.04605
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 6/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0341 - acc: 0.9872 - val_loss: 0.0494 - val_acc: 0.9830
#
# Epoch 00006: val_loss did not improve from 0.04605
# Epoch 7/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0319 - acc: 0.9881 - val_loss: 0.0511 - val_acc: 0.9827
#
# Epoch 00007: val_loss did not improve from 0.04605
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 8/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0292 - acc: 0.9891 - val_loss: 0.0527 - val_acc: 0.9826
#
# Epoch 00008: val_loss did not improve from 0.04605
# Epoch 00008: early stopping
# ***************************************************
# *******************   fold  5   *******************
# ***************************************************
# model/biLSTM_fold_5.model
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/30
# 143614/143614 [==============================] - 40s 275us/step - loss: 0.1183 - acc: 0.9650 - val_loss: 0.0498 - val_acc: 0.9824
#
# Epoch 00001: val_loss improved from inf to 0.04975, saving model to model/biLSTM_fold_5.model
# Epoch 2/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0491 - acc: 0.9823 - val_loss: 0.0473 - val_acc: 0.9831
#
# Epoch 00002: val_loss improved from 0.04975 to 0.04727, saving model to model/biLSTM_fold_5.model
# Epoch 3/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0439 - acc: 0.9839 - val_loss: 0.0473 - val_acc: 0.9833
#
# Epoch 00003: val_loss did not improve from 0.04727
# Epoch 4/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0400 - acc: 0.9851 - val_loss: 0.0478 - val_acc: 0.9828
#
# Epoch 00004: val_loss did not improve from 0.04727
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 5/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0353 - acc: 0.9868 - val_loss: 0.0493 - val_acc: 0.9828
#
# Epoch 00005: val_loss did not improve from 0.04727
# Epoch 6/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0328 - acc: 0.9878 - val_loss: 0.0513 - val_acc: 0.9824
#
# Epoch 00006: val_loss did not improve from 0.04727
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 7/30
# 143614/143614 [==============================] - 37s 258us/step - loss: 0.0300 - acc: 0.9888 - val_loss: 0.0540 - val_acc: 0.9822
#
# Epoch 00007: val_loss did not improve from 0.04727
# Epoch 00007: early stopping
# ***************************************************
# *******************   fold  6   *******************
# ***************************************************
# model/biLSTM_fold_6.model
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/30
# 143614/143614 [==============================] - 39s 274us/step - loss: 0.1518 - acc: 0.9392 - val_loss: 0.0524 - val_acc: 0.9816
#
# Epoch 00001: val_loss improved from inf to 0.05236, saving model to model/biLSTM_fold_6.model
# Epoch 2/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0513 - acc: 0.9820 - val_loss: 0.0476 - val_acc: 0.9824
#
# Epoch 00002: val_loss improved from 0.05236 to 0.04765, saving model to model/biLSTM_fold_6.model
# Epoch 3/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0460 - acc: 0.9834 - val_loss: 0.0479 - val_acc: 0.9828
#
# Epoch 00003: val_loss did not improve from 0.04765
# Epoch 4/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0422 - acc: 0.9845 - val_loss: 0.0478 - val_acc: 0.9824
#
# Epoch 00004: val_loss did not improve from 0.04765
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 5/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0380 - acc: 0.9859 - val_loss: 0.0491 - val_acc: 0.9824
#
# Epoch 00005: val_loss did not improve from 0.04765
# Epoch 6/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0358 - acc: 0.9868 - val_loss: 0.0505 - val_acc: 0.9816
#
# Epoch 00006: val_loss did not improve from 0.04765
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 7/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0332 - acc: 0.9878 - val_loss: 0.0518 - val_acc: 0.9813
#
# Epoch 00007: val_loss did not improve from 0.04765
# Epoch 00007: early stopping
# ***************************************************
# *******************   fold  7   *******************
# ***************************************************
# model/biLSTM_fold_7.model
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/30
# 143614/143614 [==============================] - 40s 275us/step - loss: 0.1411 - acc: 0.9498 - val_loss: 0.0525 - val_acc: 0.9811
#
# Epoch 00001: val_loss improved from inf to 0.05247, saving model to model/biLSTM_fold_7.model
# Epoch 2/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0493 - acc: 0.9823 - val_loss: 0.0504 - val_acc: 0.9815
#
# Epoch 00002: val_loss improved from 0.05247 to 0.05035, saving model to model/biLSTM_fold_7.model
# Epoch 3/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0442 - acc: 0.9838 - val_loss: 0.0511 - val_acc: 0.9815
#
# Epoch 00003: val_loss did not improve from 0.05035
# Epoch 4/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0405 - acc: 0.9849 - val_loss: 0.0519 - val_acc: 0.9807
#
# Epoch 00004: val_loss did not improve from 0.05035
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 5/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0359 - acc: 0.9866 - val_loss: 0.0534 - val_acc: 0.9809
#
# Epoch 00005: val_loss did not improve from 0.05035
# Epoch 6/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0335 - acc: 0.9874 - val_loss: 0.0555 - val_acc: 0.9809
#
# Epoch 00006: val_loss did not improve from 0.05035
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 7/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0309 - acc: 0.9884 - val_loss: 0.0569 - val_acc: 0.9806
#
# Epoch 00007: val_loss did not improve from 0.05035
# Epoch 00007: early stopping
# ***************************************************
# *******************   fold  8   *******************
# ***************************************************
# model/biLSTM_fold_8.model
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/30
# 143614/143614 [==============================] - 39s 275us/step - loss: 0.1318 - acc: 0.9539 - val_loss: 0.0527 - val_acc: 0.9819
#
# Epoch 00001: val_loss improved from inf to 0.05270, saving model to model/biLSTM_fold_8.model
# Epoch 2/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0492 - acc: 0.9822 - val_loss: 0.0500 - val_acc: 0.9822
#
# Epoch 00002: val_loss improved from 0.05270 to 0.04995, saving model to model/biLSTM_fold_8.model
# Epoch 3/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0441 - acc: 0.9837 - val_loss: 0.0493 - val_acc: 0.9825
#
# Epoch 00003: val_loss improved from 0.04995 to 0.04933, saving model to model/biLSTM_fold_8.model
# Epoch 4/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0406 - acc: 0.9849 - val_loss: 0.0500 - val_acc: 0.9826
#
# Epoch 00004: val_loss did not improve from 0.04933
# Epoch 5/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0370 - acc: 0.9861 - val_loss: 0.0508 - val_acc: 0.9824
#
# Epoch 00005: val_loss did not improve from 0.04933
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 6/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0325 - acc: 0.9876 - val_loss: 0.0532 - val_acc: 0.9820
#
# Epoch 00006: val_loss did not improve from 0.04933
# Epoch 7/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0299 - acc: 0.9887 - val_loss: 0.0553 - val_acc: 0.9819
#
# Epoch 00007: val_loss did not improve from 0.04933
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 8/30
# 143614/143614 [==============================] - 37s 258us/step - loss: 0.0274 - acc: 0.9898 - val_loss: 0.0567 - val_acc: 0.9817
#
# Epoch 00008: val_loss did not improve from 0.04933
# Epoch 00008: early stopping
# ***************************************************
# *******************   fold  9   *******************
# ***************************************************
# model/biLSTM_fold_9.model
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/30
# 143614/143614 [==============================] - 40s 276us/step - loss: 0.1412 - acc: 0.9434 - val_loss: 0.0537 - val_acc: 0.9808
#
# Epoch 00001: val_loss improved from inf to 0.05373, saving model to model/biLSTM_fold_9.model
# Epoch 2/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0507 - acc: 0.9818 - val_loss: 0.0513 - val_acc: 0.9818
#
# Epoch 00002: val_loss improved from 0.05373 to 0.05127, saving model to model/biLSTM_fold_9.model
# Epoch 3/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0453 - acc: 0.9833 - val_loss: 0.0522 - val_acc: 0.9817
#
# Epoch 00003: val_loss did not improve from 0.05127
# Epoch 4/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0415 - acc: 0.9845 - val_loss: 0.0526 - val_acc: 0.9817
#
# Epoch 00004: val_loss did not improve from 0.05127
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 5/30
# 143614/143614 [==============================] - 37s 260us/step - loss: 0.0371 - acc: 0.9860 - val_loss: 0.0534 - val_acc: 0.9816
#
# Epoch 00005: val_loss did not improve from 0.05127
# Epoch 6/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0347 - acc: 0.9868 - val_loss: 0.0552 - val_acc: 0.9814
#
# Epoch 00006: val_loss did not improve from 0.05127
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 7/30
# 143614/143614 [==============================] - 37s 259us/step - loss: 0.0322 - acc: 0.9879 - val_loss: 0.0578 - val_acc: 0.9812
#
# Epoch 00007: val_loss did not improve from 0.05127
# Epoch 00007: early stopping

# %%
# create prediction csv
model_predict(lstm_model, save_model_name, num_fold, X_test, list_class)
# release memory
del lstm_model
gc.collect()
# Out:
# Processing model 0 ...
# Processing model 1 ...
# Processing model 2 ...
# Processing model 3 ...
# Processing model 4 ...
# Processing model 5 ...
# Processing model 6 ...
# Processing model 7 ...
# Processing model 8 ...
# Processing model 9 ...

# %%
save_model_name = 'biLSTM_attention'
lstm_attention_model = biLSTM_attention_model(embed_size, max_feature, max_len, embedding_matrix)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1277     try:
# -> 1278       return fn(*args)
#    1279     except errors.OpError as e:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1262       return self._call_tf_sessionrun(
# -> 1263           options, feed_dict, fetch_list, target_list, run_metadata)
#    1264
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1349         self._session, options, feed_dict, fetch_list, target_list,
# -> 1350         run_metadata)
#    1351
#
# InternalError: GPU sync failed
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-26-7db0815743bb> in <module>()
#       1 save_model_name = 'biLSTM_attention'
# ----> 2 lstm_attention_model = biLSTM_attention_model(embed_size, max_feature, max_len, embedding_matrix)
#
# D:\file\Machine Learning\Toxic Comment Classification Challenge\model.py in biLSTM_attention_model(embed_size, max_feature, max_len, embedding_matrix)
#      30
#      31     X_input = Input((max_len, ))
# ---> 32     X = Embedding(max_feature, embed_size, weights=[embedding_matrix])(X_input)
#      33     X = Bidirectional(CuDNNLSTM(64, return_sequences=True))(X)
#      34     X = Bidirectional(CuDNNLSTM(64, return_sequences=True))(X)
#
# ~\Anaconda3\lib\site-packages\keras\engine\base_layer.py in __call__(self, inputs, **kwargs)
#     434                 # Load weights that were specified at layer instantiation.
#     435                 if self._initial_weights is not None:
# --> 436                     self.set_weights(self._initial_weights)
#     437
#     438             # Raise exceptions in case the input is not compatible
#
# ~\Anaconda3\lib\site-packages\keras\engine\base_layer.py in set_weights(self, weights)
#    1049             return
#    1050         weight_value_tuples = []
# -> 1051         param_values = K.batch_get_value(params)
#    1052         for pv, p, w in zip(param_values, params, weights):
#    1053             if pv.shape != w.shape:
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in batch_get_value(ops)
#    2388     """
#    2389     if ops:
# -> 2390         return get_session().run(ops)
#    2391     else:
#    2392         return []
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in get_session()
#     195                 # not already marked as initialized.
#     196                 is_initialized = session.run(
# --> 197                     [tf.is_variable_initialized(v) for v in candidate_vars])
#     198                 uninitialized_vars = []
#     199                 for flag, v in zip(is_initialized, candidate_vars):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     875     try:
#     876       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 877                          run_metadata_ptr)
#     878       if run_metadata:
#     879         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1098     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1099       results = self._do_run(handle, final_targets, final_fetches,
# -> 1100                              feed_dict_tensor, options, run_metadata)
#    1101     else:
#    1102       results = []
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1270     if handle is None:
#    1271       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1272                            run_metadata)
#    1273     else:
#    1274       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1289         except KeyError:
#    1290           pass
# -> 1291       raise type(e)(node_def, op, message)
#    1292
#    1293   def _extend_graph(self):
#
# InternalError: GPU sync failed

# %%
kfold_train(kfold, X_df, y_df, lstm_attention_model, save_model_name)
# Out:
# ***************************************************
# *******************   fold  0   *******************
# ***************************************************
# model/biLSTM_attention_fold_0.model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 100, 300)          6000000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 100, 128)          187392
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 100, 128)          99328
# _________________________________________________________________
# attention_1 (Attention)      (None, 128)               228
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 6,295,594
# Trainable params: 6,295,594
# Non-trainable params: 0
# _________________________________________________________________
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/30
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-17-bf15a7f2da0d> in <module>()
# ----> 1 kfold_train(kfold, X_df, y_df, lstm_attention_model, save_model_name)
#
# D:\file\Machine Learning\Toxic Comment Classification Challenge\utils.py in kfold_train(kfold, X_df, y_df, model, save_model_name)
#      60         history = model.fit(X_train, y_train, batch_size=512,
#      61                             epochs=30, validation_data=[X_val, y_val],
# ---> 62                             callbacks=[early_stopping, model_checkpoint, reduce_lr])
#      63
#      64         # reset model weights for next fold
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     517             None, None,
#     518             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 519             c_api.TF_GetCode(self.status.status))
#     520     # Delete the underlying status object from memory otherwise it stays alive
#     521     # as there is a reference to status from this from the traceback due to
#
# InternalError: Failed to call ThenRnnForward with model config: [rnn_mode, rnn_input_mode, rnn_direction_mode]: 2, 0, 0 , [num_layers, input_size, num_units, dir_count, seq_length, batch_size]: [1, 128, 64, 1, 100, 512]
# 	 [[Node: bidirectional_2/CudnnRNN = CudnnRNN[T=DT_FLOAT, _class=["loc:@training/Adam/gradients/bidirectional_2/CudnnRNN_grad/CudnnRNNBackprop"], direction="unidirectional", dropout=0, input_mode="linear_input", is_training=true, rnn_mode="lstm", seed=87654321, seed2=0, _device="/job:localhost/replica:0/task:0/device:GPU:0"](bidirectional_2/transpose, bidirectional_2/ExpandDims_1, bidirectional_2/ExpandDims_1, bidirectional_2/concat)]]
# 	 [[Node: loss/mul/_205 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_2596_loss/mul", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]

# %%
model_predict(lstm_attention_model, save_model_name, num_fold, X_test, list_class)
